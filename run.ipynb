# %%
cd /content/drive/MyDrive/Colab Notebooks/Ai_in_games/Group_Assgn_2/assgn_2_py
# Out:
# /content/drive/MyDrive/Colab Notebooks/Ai_in_games/Group_Assgn_2/assgn_2_py

# %%
# !python main.py -h
# Out:
# usage: main.py [-h] [-l [LAKE]] [-m [MODEL]] [-g [GAMMA]] [-t [THETA]]
#                [-i [MAX_ITERATIONS]] [-e [MAX_EPISODES]] [-r [ETA]]
#                [-ep [EPSILON]]
#
# Exploring reinfocement lerning algorithms
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -l [LAKE], --lake [LAKE]
#                         Choose lake type Small Lake(1) Big Lake(2)
#   -m [MODEL], --model [MODEL]
#                         Choose model to evaluate on Lake Model: Based (1)
#                         Tabular model-free (2) Non-Tabular model-free (3) All
#                         (4) Human Interface(5)
#   -g [GAMMA], --gamma [GAMMA]
#                         white value for discont factor
#   -t [THETA], --theta [THETA]
#                         initialize the value for theta
#   -i [MAX_ITERATIONS], --max_iterations [MAX_ITERATIONS]
#                         maximum number of iterations for policy and value
#                         iterations
# ...

# %%
# !python main.py -m 5
# Out:
# ^C

# %%
# !python main.py -m 3 -ep 1 -e 2000000 -l 2
